# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkuhodomo/Data_Science/blob/main/Correlation_Analysis_Heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **학생들의 만족도 조사 영향 요인 상관 계수 분석 결과 히트맵**

# %%
from google.colab import files
import io
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Upload the file
uploaded = files.upload()

# Display the uploaded file names
print("Uploaded files:", uploaded.keys())

# Use the correct filename when reading the Excel file
filename = list(uploaded.keys())[0]  # Use the first uploaded file
df = pd.read_excel(io.BytesIO(uploaded[filename]))

# Select numeric columns for correlation analysis
numeric_columns = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_matrix = numeric_columns.corr()

# Create a heatmap with annotations using seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
#      <input type="file" id="files-c8a0674c-8358-4e0f-9271-327d7c341133" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8a0674c-8358-4e0f-9271-327d7c341133">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 만족도에 영향을 주는 주요 요인 = 상관 계수가 0.6 이상인 것입니다.
#
# 그 결과, 수업 시간, 수업의 질, 성적의 공정성, 수업 내용, 수업 자료가 유의미한 영향을 주는 것으로 나타났습니다.
